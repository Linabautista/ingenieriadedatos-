# %%
import pandas as pd

# %%
inventario = pd.read_excel("actividad.tienda.xlsx", sheet_name="Inventario")
ventas = pd.read_excel("actividad.tienda.xlsx", sheet_name="Ventas")
compras = pd.read_excel("actividad.tienda.xlsx", sheet_name="Compras")

# %%
import os
os.listdir()
# Out:
# ['.config', 'actividad.tienda.xlsx', 'sample_data']

# %%
inventario.info ()
ventas.info ()
compras.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Producto          11 non-null     object
#  1   inventario        11 non-null     float64
#  2   costo             7 non-null      float64
#  3   venta             7 non-null      float64
#  4   Inventario nuevo  7 non-null      float64
#  5   Unnamed: 5        0 non-null      float64
#  6   Unnamed: 6        5 non-null      object
#  7   Unnamed: 7        5 non-null      float64
# dtypes: float64(6), object(2)
# memory usage: 964.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id venta      5 non-null      float64
#  1   Producto      5 non-null      object
#  2   Cantidad      5 non-null      float64
# ...

# %%
inventario.isnull().sum ()
ventas.isnull().sum ()
compras.isnull().sum ()
# Out:
# Compra        5
# Producto      5
# Cantidad      5
# Precio U      5
# Precio        1
# Unnamed: 5    6
# dtype: int64

# %%
inventario
# Out:
#                         Producto  inventario  costo  venta  Inventario nuevo  \
# 0             galletas chocolate         7.0    1.5    3.0               5.0
# 1         galletas mms chocolate         7.0    2.0    4.0               7.0
# 2   galleta red velvet chocolate         7.0    2.0    4.0               6.0
# 3                    cinamonroll         2.0    4.0    8.0               2.0
# 4                       tiramisu         2.0    4.0    8.0               0.0
# 5          cheese cake arandanos         2.0    4.0    8.0               2.0
# 6             cheese cake cereza         2.0    4.0    8.0               2.0
# 7                            NaN         NaN    NaN    NaN               NaN
# 8                            NaN         NaN    NaN    NaN               NaN
# 9            Presupuesto inicial        50.0    NaN    NaN               NaN
# 10                  Total Ventas        38.0    NaN    NaN               NaN
# ...

# %%
inventario = pd.read_excel("Actividad.xlsx", sheet_name="Inventario")
ventas = pd.read_excel("Actividad.xlsx", sheet_name="Ventas")
compras = pd.read_excel("Actividad.xlsx", sheet_name="Compras")

# %%
inventario["Inventario nuevo"].mean()
# Out:
# np.float64(3.4285714285714284)

# %%
inventario["Inventario nuevo"].median()
# Out:
# 2.0

# %%
inventario["Inventario nuevo"].mode()
# Out:
# 0    2.0
# Name: Inventario nuevo, dtype: float64

# %%
inventario["Inventario nuevo"].max()
# Out:
# 7.0

# %%
inventario["Inventario nuevo"].min()
# Out:
# 0.0

# %%
ventas
# Out:
#    id venta            Producto  Cantidad Costo U  Costo Total  Precio U  \
# 0       1.0            tiramisu       2.0       4          8.0       8.0
# 1       2.0         galleta red       1.0       1          2.0       2.0
# 2       3.0   galleta chocolate       2.0     1.5          3.0       2.5
# 3       4.0         galleta red       2.0       2          4.0       4.0
# 4       5.0  galletas chocolate       2.0     1.5          3.0       2.5
# 5       NaN                 NaN       NaN     NaN          NaN       NaN
# 6       NaN                 NaN       NaN     NaN          NaN       NaN
# 7       NaN                 NaN       NaN  media           3.8       NaN
#
#    Precio total  Ganancia
# 0          16.0       8.0
# 1           4.0       2.0
# 2           5.0       2.0
# 3           8.0       4.0
# 4           5.0       2.0
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN

# %%
ventas["Precio total"].sum()
# Out:
# np.float64(38.0)

# %%
ventas["Ganancia"].sum()
# Out:
# np.float64(18.0)

# %%
ventas.groupby("Producto")["Cantidad"].sum()
# Out:
# Producto
# galleta chocolate     2.0
# galleta red           3.0
# galletas chocolate    2.0
# tiramisu              2.0
# Name: Cantidad, dtype: float64

# %%
import matplotlib.pyplot as plt

ventas.groupby("Producto")["Cantidad"].sum().plot(kind="bar")

plt.title("Cantidad vendida por producto")
plt.xlabel("Producto")
plt.ylabel("Cantidad vendida")

plt.show()

# %% [markdown]
# hipotesis 1 el tiramisu fue el producto con mas aalida pues terminamos con 0 productos

# %% [markdown]
# hipotesis 2 las galletas de m& m se no se vendieron pjes no se registro ninguna venta

# %% [markdown]
# se concluye que los postres tipo tiramisu tienen mayor demanda
